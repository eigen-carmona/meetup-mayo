# %%
from ortools.sat.python import cp_model
import pandas as pd

# %%
#Generando instancias del modelo y el solver:
model = cp_model.CpModel()
solver = cp_model.CpSolver()

# %%
#Generando variables del problema:
talks = pd.read_csv('PyConLatam.csv', ";")

# %%
talks
# Out:
#                                                Charla               Ponentes  \
# 0                        “Phyton: Python para fisica”              Carlangas
# 1                             “Introducción a Pandas”                Juanito
# 2               “Quantum Machine Learning con Python”             Seth Lloyd
# 3                        “Buenas prácticas con NumPy”              Carlangas
# 4                       “Mejores prácticas con NumBa”              Carlangas
# 5   “¿Es python una buena idea para el cómputo cie...  Seth Lloyd, Carlangas
# 6   “Testing en cómputo científico y por qué los c...          Pedro Navajas
# 7                “Testing en AI y cómo evitar Skynet”           Sarah Connor
# 8                      “Python para la industria 4.0”                El Fede
# 9                                     “Muerte al OOP”             El Barriuc
# 10                             “Scripts para la vida”                 MichBc
# 11                       “¿Deberían todos programar?”  Juanito, Sarah Connor
#
#    Tipo de charla Turno preferido  Duración            Dias posibles
# 0     Conferencia           tarde        45  jueves, viernes, sábado
# 1          Taller        mediodía        60          viernes, sábado
# 2          Taller          mañana        60                   sábado
# 3          Taller        mediodía        30  jueves, viernes, sábado
# 4          Taller           tarde        30  jueves, viernes, sábado
# 5    Mesa Redonda           tarde        90                   sábado
# 6     Conferencia        mediodía        60                  viernes
# 7     Conferencia        mediodía        60                   sábado
# 8     Conferencia          mañana        45                   jueves
# 9     Conferencia           tarde        60          viernes, sábado
# 10         Taller        mediodía        45           jueves, sábado
# 11   Mesa Redonda          mañana        90  jueves, viernes, sábado

# %%
for i in range(len(talks)):
    print(talks.loc[i])
    print()
# Out:
# Charla             “Phyton: Python para fisica”
# Ponentes                              Carlangas
# Tipo de charla                      Conferencia
# Turno preferido                           tarde
# Duración                                     45
# Dias posibles           jueves, viernes, sábado
# Name: 0, dtype: object
#
# Charla             “Introducción a Pandas”
# Ponentes                           Juanito
# Tipo de charla                      Taller
# Turno preferido                   mediodía
# Duración                                60
# Dias posibles              viernes, sábado
# Name: 1, dtype: object
#
# Charla             “Quantum Machine Learning con Python”
# Ponentes                                      Seth Lloyd
# Tipo de charla                                    Taller
# Turno preferido                                   mañana
# Duración                                              60
# Dias posibles                                     sábado
# Name: 2, dtype: object
#
# Charla             “Buenas prácticas con NumPy”
# Ponentes                              Carlangas
# Tipo de charla                           Taller
# Turno preferido                        mediodía
# Duración                                     30
# Dias posibles           jueves, viernes, sábado
# Name: 3, dtype: object
#
# Charla             “Mejores prácticas con NumBa”
# Ponentes                               Carlangas
# Tipo de charla                            Taller
# Turno preferido                            tarde
# Duración                                      30
# Dias posibles            jueves, viernes, sábado
# Name: 4, dtype: object
#
# Charla             “¿Es python una buena idea para el cómputo cie...
# Ponentes                                       Seth Lloyd, Carlangas
# Tipo de charla                                          Mesa Redonda
# Turno preferido                                                tarde
# Duración                                                          90
# Dias posibles                                                 sábado
# Name: 5, dtype: object
#
# Charla             “Testing en cómputo científico y por qué los c...
# Ponentes                                               Pedro Navajas
# Tipo de charla                                           Conferencia
# Turno preferido                                             mediodía
# Duración                                                          60
# Dias posibles                                                viernes
# Name: 6, dtype: object
#
# Charla             “Testing en AI y cómo evitar Skynet”
# Ponentes                                   Sarah Connor
# Tipo de charla                              Conferencia
# Turno preferido                                mediodía
# Duración                                             60
# Dias posibles                                    sábado
# Name: 7, dtype: object
#
# Charla             “Python para la industria 4.0”
# Ponentes                                  El Fede
# Tipo de charla                        Conferencia
# Turno preferido                            mañana
# Duración                                       45
# Dias posibles                              jueves
# Name: 8, dtype: object
#
# Charla             “Muerte al OOP”
# Ponentes                El Barriuc
# Tipo de charla         Conferencia
# Turno preferido              tarde
# Duración                        60
# Dias posibles      viernes, sábado
# Name: 9, dtype: object
#
# Charla             “Scripts para la vida”
# Ponentes                           MichBc
# Tipo de charla                     Taller
# Turno preferido                  mediodía
# Duración                               45
# Dias posibles              jueves, sábado
# Name: 10, dtype: object
#
# Charla             “¿Deberían todos programar?”
# Ponentes                  Juanito, Sarah Connor
# Tipo de charla                     Mesa Redonda
# Turno preferido                          mañana
# Duración                                     90
# Dias posibles           jueves, viernes, sábado
# Name: 11, dtype: object
